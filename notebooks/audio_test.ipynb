# %%
import torch
import torchaudio
from IPython.display import Audio

# %%
audio, sample = torchaudio.load("../test.wav")

# %%
audio
# Out:
# tensor([[0., 0., 0.,  ..., 0., 0., 0.]])

# %%
Audio("../test.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
